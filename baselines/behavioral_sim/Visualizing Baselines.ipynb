# %%
from baselines.common import plot_util as pu
import matplotlib.pyplot as plt
import numpy as np

# %%
results = pu.load_results('/home/jpalaks/research/baselines-RAISE/baselines/behavioral_sim/logs')
print(len(results))
r = results[0]
# Out:
# skipping progress file in  /home/jpalaks/research/baselines-RAISE/baselines/behavioral_sim/logs/test_ddpg empty data
# 4

# %%
plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
# plt.ylim(-10, 10)

# %%
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))
